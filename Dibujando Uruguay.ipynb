# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import shapely as sp

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
deptos = gpd.read_file('./Mapas Vectoriales año 2011/ine_depto.shp')

# %%
deptos.plot()

# %%
lpg = gpd.read_file('Mapas Vectoriales año 2011/ine_loc11_pg.shp')

# %%
lpg.plot()

# %%
lpt = gpd.read_file('Mapas Vectoriales año 2011/ine_loc11_pt.shp')

# %%
lpt.plot()

# %%
zonas = gpd.read_file('Mapas Vectoriales año 2011/ine_zonas_11.shp')

# %%
zonas.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-fe49370d9878> in <module>()
# ----> 1 zonas.plot()
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     445     def plot(self, *args, **kwargs):
#     446
# --> 447         return plot_dataframe(self, *args, **kwargs)
#     448
#     449     plot.__doc__ = plot_dataframe.__doc__
#
# /Users/danielbonini/anaconda/lib/python3.6/site-packages/geopandas/plotting.py in plot_dataframe(s, column, cmap, color, linewidth, categorical, legend, ax, scheme, k, vmin, vmax, figsize, **color_kwds)
#     238         return plot_series(s.geometry, cmap=cmap, color=color,
#     239                            ax=ax, linewidth=linewidth, figsize=figsize,
# --> 240                            **color_kwds)
#     241     else:
# ...

# %%
zonas
